# %%
# %pip install scikit-learn
# %pip install pandas
from timeit import default_timer as timer
from sklearn import metrics
from sklearn.model_selection import train_test_split
import warnings
from IPython.display import HTML
warnings.filterwarnings('ignore')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/u12c0dff4e02a1a3314ab4ead8fc31d6/.local/lib/python3.11/site-packages (1.3.1)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /home/u12c0dff4e02a1a3314ab4ead8fc31d6/.local/lib/python3.11/site-packages (from scikit-learn) (1.26.0)
# Requirement already satisfied: scipy>=1.5.0 in /home/u12c0dff4e02a1a3314ab4ead8fc31d6/.local/lib/python3.11/site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /home/u12c0dff4e02a1a3314ab4ead8fc31d6/.local/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/u12c0dff4e02a1a3314ab4ead8fc31d6/.local/lib/python3.11/site-packages (from scikit-learn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/u12c0dff4e02a1a3314ab4ead8fc31d6/.local/lib/python3.11/site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.23.2 in /home/u12c0dff4e02a1a3314ab4ead8fc31d6/.local/lib/python3.11/site-packages (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/u12c0dff4e02a1a3314ab4ead8fc31d6/.local/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/u12c0dff4e02a1a3314ab4ead8fc31d6/.local/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df = pd.read_csv("fetal_health.csv")

# %%
df.isnull().sum()
# Out:
# baseline value                                            0
# accelerations                                             0
# fetal_movement                                            0
# uterine_contractions                                      0
# light_decelerations                                       0
# severe_decelerations                                      0
# prolongued_decelerations                                  0
# abnormal_short_term_variability                           0
# mean_value_of_short_term_variability                      0
# percentage_of_time_with_abnormal_long_term_variability    0
# mean_value_of_long_term_variability                       0
# histogram_width                                           0
# histogram_min                                             0
# histogram_max                                             0
# histogram_number_of_peaks                                 0
# histogram_number_of_zeroes                                0
# histogram_mode                                            0
# histogram_mean                                            0
# histogram_median                                          0
# histogram_variance                                        0
# histogram_tendency                                        0
# fetal_health                                              0
# dtype: int64

# %%
x = df.drop(['fetal_health'],axis=1)
y = df['fetal_health']

# %%
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=43)
x_train.shape, x_test.shape, y_train.shape
# Out:
# ((1913, 21), (213, 21), (1913,))

# %%
# %pip install notebook scikit-learn-intelex
from sklearnex import patch_sklearn
patch_sklearn()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: notebook in /srv/jupyter/python-venv/lib/python3.11/site-packages (7.0.4)
# Requirement already satisfied: scikit-learn-intelex in /home/u12c0dff4e02a1a3314ab4ead8fc31d6/.local/lib/python3.11/site-packages (2023.2.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from notebook) (2.7.3)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from notebook) (2.25.0)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from notebook) (4.0.6)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from notebook) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from notebook) (6.3.3)
# Requirement already satisfied: daal4py==2023.2.1 in /home/u12c0dff4e02a1a3314ab4ead8fc31d6/.local/lib/python3.11/site-packages (from scikit-learn-intelex) (2023.2.1)
# Requirement already satisfied: scikit-learn>=0.22 in /home/u12c0dff4e02a1a3314ab4ead8fc31d6/.local/lib/python3.11/site-packages (from scikit-learn-intelex) (1.3.1)
# Requirement already satisfied: daal==2023.2.1 in /home/u12c0dff4e02a1a3314ab4ead8fc31d6/.local/lib/python3.11/site-packages (from daal4py==2023.2.1->scikit-learn-intelex) (2023.2.1)
# Requirement already satisfied: numpy>=1.19 in /home/u12c0dff4e02a1a3314ab4ead8fc31d6/.local/lib/python3.11/site-packages (from daal4py==2023.2.1->scikit-learn-intelex) (1.26.0)
# Requirement already satisfied: tbb==2021.* in /home/u12c0dff4e02a1a3314ab4ead8fc31d6/.local/lib/python3.11/site-packages (from daal==2023.2.1->daal4py==2023.2.1->scikit-learn-intelex) (2021.10.0)
# Requirement already satisfied: anyio>=3.1.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.0.0)
# Requirement already satisfied: argon2-cffi in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (23.1.0)
# Requirement already satisfied: jinja2 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.2)
# Requirement already satisfied: jupyter-client>=7.4.4 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.3.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.3.1)
# Requirement already satisfied: jupyter-events>=0.6.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.7.0)
# Requirement already satisfied: jupyter-server-terminals in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.8.0)
# Requirement already satisfied: nbformat>=5.3.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.9.2)
# Requirement already satisfied: overrides in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.4.0)
# Requirement already satisfied: packaging in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (23.1)
# Requirement already satisfied: prometheus-client in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.17.1)
# Requirement already satisfied: pyzmq>=24 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.1)
# Requirement already satisfied: send2trash>=1.8.2 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.17.1)
# Requirement already satisfied: traitlets>=5.6.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.0)
# Requirement already satisfied: websocket-client in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.6.3)
# Requirement already satisfied: async-lru>=1.0.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook) (2.0.4)
# Requirement already satisfied: ipykernel in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook) (6.25.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook) (2.2.0)
# Requirement already satisfied: babel>=2.10 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook) (2.12.1)
# Requirement already satisfied: json5>=0.9.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook) (0.9.14)
# Requirement already satisfied: jsonschema>=4.18.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook) (4.19.1)
# Requirement already satisfied: requests>=2.31 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook) (2.31.0)
# Requirement already satisfied: scipy>=1.5.0 in /home/u12c0dff4e02a1a3314ab4ead8fc31d6/.local/lib/python3.11/site-packages (from scikit-learn>=0.22->scikit-learn-intelex) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /home/u12c0dff4e02a1a3314ab4ead8fc31d6/.local/lib/python3.11/site-packages (from scikit-learn>=0.22->scikit-learn-intelex) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/u12c0dff4e02a1a3314ab4ead8fc31d6/.local/lib/python3.11/site-packages (from scikit-learn>=0.22->scikit-learn-intelex) (3.2.0)
# Requirement already satisfied: idna>=2.8 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jinja2->jupyter-server<3,>=2.4.0->notebook) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (0.10.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (3.10.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (6.0.0)
# Requirement already satisfied: defusedxml in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.2.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (3.0.1)
# Requirement already satisfied: nbclient>=0.5.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.16.1)
# Requirement already satisfied: tinycss2 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.2.1)
# Requirement already satisfied: fastjsonschema in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook) (2023.7.22)
# Requirement already satisfied: ptyprocess in /srv/jupyter/python-venv/lib/python3.11/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->notebook) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /srv/jupyter/python-venv/lib/python3.11/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook) (21.2.0)
# Requirement already satisfied: comm>=0.1.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (8.15.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.1.6)
# Requirement already satisfied: nest-asyncio in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (1.5.8)
# Requirement already satisfied: psutil in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (5.9.5)
# Requirement already satisfied: six>=1.9.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.16.0)
# Requirement already satisfied: webencodings in /srv/jupyter/python-venv/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: backcall in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.2.0)
# Requirement already satisfied: decorator in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.19.0)
# Requirement already satisfied: pickleshare in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (3.0.39)
# Requirement already satisfied: stack-data in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (4.8.0)
# Requirement already satisfied: fqdn in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (1.5.1)
# Requirement already satisfied: isoduration in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (2.4)
# Requirement already satisfied: uri-template in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.5)
# Requirement already satisfied: pycparser in /srv/jupyter/python-venv/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.8.3)
# Requirement already satisfied: wcwidth in /srv/jupyter/python-venv/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.2.6)
# Requirement already satisfied: arrow>=0.15.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (1.2.3)
# Requirement already satisfied: executing>=1.2.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (2.4.0)
# Requirement already satisfied: pure-eval in /srv/jupyter/python-venv/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
df.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# 0                             73.0                                   0.5
# 1                             17.0                                   2.1
# 2                             16.0                                   2.1
# 3                             16.0                                   2.4
# 4                             16.0                                   2.4
#
#    percentage_of_time_with_abnormal_long_term_variability  ...  histogram_min  \
# 0                                               43.0       ...           62.0
# 1                                                0.0       ...           68.0
# 2                                                0.0       ...           68.0
# 3                                                0.0       ...           53.0
# 4                                                0.0       ...           53.0
#
#    histogram_max  histogram_number_of_peaks  histogram_number_of_zeroes  \
# 0          126.0                        2.0                         0.0
# 1          198.0                        6.0                         1.0
# 2          198.0                        5.0                         1.0
# 3          170.0                       11.0                         0.0
# 4          170.0                        9.0                         0.0
#
#    histogram_mode  histogram_mean  histogram_median  histogram_variance  \
# 0           120.0           137.0             121.0                73.0
# 1           141.0           136.0             140.0                12.0
# 2           141.0           135.0             138.0                13.0
# 3           137.0           134.0             137.0                13.0
# 4           137.0           136.0             138.0                11.0
#
#    histogram_tendency  fetal_health
# 0                 1.0           2.0
# 1                 0.0           1.0
# 2                 0.0           1.0
# 3                 1.0           1.0
# 4                 1.0           1.0
#
# [5 rows x 22 columns]

# %%
model=[]
acc=[]

# %% [markdown]
# model=[]
# accuracy=[]

# %%
from sklearnex.svm import SVC
from sklearnex import patch_sklearn
from sklearn.metrics import classification_report
patch_sklearn()

SVM = SVC(gamma='auto')

SVM.fit(x_train,y_train)

predicted_values = SVM.predict(x_test)

x = metrics.accuracy_score(y_test, predicted_values)
acc.append(x)
model.append('SVM')
print("SVM's Accuracy is: ", x)

print(classification_report(y_test,predicted_values))
#Here, SVM Is presented! More follows.
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
# SVM's Accuracy is:  0.8075117370892019
#               precision    recall  f1-score   support
#
#          1.0       0.80      1.00      0.89       167
#          2.0       1.00      0.12      0.21        25
#          3.0       1.00      0.10      0.17        21
#
#     accuracy                           0.81       213
#    macro avg       0.93      0.41      0.43       213
# weighted avg       0.85      0.81      0.74       213

# %%
from sklearnex.linear_model import LogisticRegression
from sklearnex import patch_sklearn
patch_sklearn()

LogReg = LogisticRegression(random_state=2)

LogReg.fit(x_train,y_train)

predicted_values = LogReg.predict(x_test)

x = metrics.accuracy_score(y_test, predicted_values)
acc.append(x)
model.append('Logistic Regression')
print("Logistic Regression's Accuracy is: ", x)

print(classification_report(y_test,predicted_values))
#Logistic Regression here, More to follow.
# Out:
# Logistic Regression's Accuracy is:  0.9014084507042254
#               precision    recall  f1-score   support
#
#          1.0       0.91      0.99      0.95       167
#          2.0       0.72      0.52      0.60        25
#          3.0       1.00      0.67      0.80        21
#
#     accuracy                           0.90       213
#    macro avg       0.88      0.72      0.78       213
# weighted avg       0.90      0.90      0.89       213
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
from sklearn.neighbors import KNeighborsClassifier
patch_sklearn()

params = {
    'n_neighbors': 40,
    'weights': 'distance',
    'n_jobs': -1
}
start = timer()
knn = KNeighborsClassifier(**params).fit(x_train, y_train)
x = knn.score(x_train, y_train)
print("KNN's Accuracy is: ", x)
print(classification_report(y_test,predicted_values))
#KNN comes here, More follows.
# Out:
# KNN's Accuracy is:  0.9832723470987977
#               precision    recall  f1-score   support
#
#          1.0       0.91      0.99      0.95       167
#          2.0       0.72      0.52      0.60        25
#          3.0       1.00      0.67      0.80        21
#
#     accuracy                           0.90       213
#    macro avg       0.88      0.72      0.78       213
# weighted avg       0.90      0.90      0.89       213
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
